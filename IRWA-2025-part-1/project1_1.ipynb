# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re
from collections import Counter
from wordcloud import WordCloud

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Usuari\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuari\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Part I: Data Preparation

# %%
df = pd.read_json("../IRWA-2025-data/fashion_products_dataset.json")
print(df.shape)
df.head()
# Out:
# (28080, 17)
#                                     _id actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# 2  Yorker trackpants made from 100% rich combed c...  68% off
# 3  Yorker trackpants made from 100% rich combed c...  69% off
# 4  Yorker trackpants made from 100% rich combed c...  68% off
#
#                                               images  out_of_stock  \
# 0  [https://rukminim1.flixcart.com/image/128/128/...         False
# 1  [https://rukminim1.flixcart.com/image/128/128/...         False
# 2  [https://rukminim1.flixcart.com/image/128/128/...         False
# 3  [https://rukminim1.flixcart.com/image/128/128/...         False
# 4  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                 pid                                    product_details  \
# 0  TKPFCZ9EA7H5FYZH  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1  TKPFCZ9EJZV2UVRZ  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
# 2  TKPFCZ9EHFCY5Z4Y  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...
# 3  TKPFCZ9ESZZ7YWEF  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...
# 4  TKPFCZ9EVXKBSUD7  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...
#
#               seller selling_price sub_category  \
# 0  Shyam Enterprises           921   Bottomwear
# 1  Shyam Enterprises           499   Bottomwear
# 2  Shyam Enterprises           931   Bottomwear
# 3  Shyam Enterprises           911   Bottomwear
# 4  Shyam Enterprises           943   Bottomwear
#
#                                  title  \
# 0   Solid Women Multicolor Track Pants
# 1           Solid Men Blue Track Pants
# 2     Solid Men Multicolor Track Pants
# 3   Solid Women Multicolor Track Pants
# 4  Solid Women Brown, Grey Track Pants
#
#                                                  url
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...

# %% [markdown]
# ### 1. Preprocessing
#
# As a first step, you must pre-process the documents. In particular, for the text fields (title,
# description) you should:
#
# - Removing stop words
# - Tokenization
# - Removing punctuation marks
# - Stemming
# - and... anything else you think it's needed (bonus point)

# %%
def build_terms(line):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    
    line = re.sub(r"[^a-zA-Z0-9\s\-x]", " ", line) # removing punctuation and digits
    line = line.lower() # transform in lowercase
    line = line.split() # tokenization
    line = [w for w in line if w not in stop_words] # remove stop words
    line = [stemmer.stem(w) for w in line] # stemming
    # extra: normalize accents and numbers

    return line

# %% [markdown]
# ### 2. Select columns
#
# Take into account that for future queries, the final output must return (when present) the
# following information for each of the selected documents:
# pid, title, description, brand, category, sub_category, product_details, seller, out_of_stock,
# selling_price, discount, actual_price, average_rating, url.

# %%
keep = ["pid", "title", "description", "brand", "category", "sub_category",
        "product_details", "seller", "out_of_stock", "selling_price",
        "discount", "actual_price", "average_rating", "url"]

df = df.reindex(columns=keep)

# %%
df.head()
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...  Shyam Enterprises
# 1  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...  Shyam Enterprises
# 2  [{'Style Code': '1005COMBO4'}, {'Closure': 'El...  Shyam Enterprises
# 3  [{'Style Code': '1005COMBO3'}, {'Closure': 'El...  Shyam Enterprises
# 4  [{'Style Code': '1005COMBO1'}, {'Closure': 'Dr...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url
# 0  https://www.flipkart.com/yorker-solid-men-mult...
# 1  https://www.flipkart.com/yorker-solid-men-blue...
# 2  https://www.flipkart.com/yorker-solid-men-mult...
# 3  https://www.flipkart.com/yorker-solid-men-mult...
# 4  https://www.flipkart.com/yorker-solid-men-brow...

# %% [markdown]
# ### 3. Categorical fields
#
# Decide how to handle the fields category, sub_category, brand, product_details, and seller during pre-processing. Should they be merged into a single text field, indexed as separate fields in the inverted index or any other alternative? Justify your choice, considering how their distinctiveness may affect retrieval effectiveness. What are pros and cons of each approach?

# %% [markdown]
# Conservamos los campos nombrados por separado y procesados, y también un campo auxiliar `extra_field` que concatenan estos cinco para mejorar el resultado de las consultas.
# La razón es porque entre los cinco campos no tienen el mismo peso por consulta, `sub_category` y `product_details` más relevantes que `seller`, o `brand` da una dimensión útil a la búsqueda por marca.
#
# - En un solo campo: Juntar los campos en uno solo, de lo simple que es olvida la distinción entre palabras, dando el mismo peso a todas ellas.
# - En campos separados: Mantenerlos por separado es más ordenado y permite dar un mayor contexto a las consultas según cada campo.

# %%
def flatten(details):
    if not isinstance(details, list):
        return {}
    merged = {}
    for detail in details:
        if isinstance(detail, dict):
            merged.update(detail)
    return merged

# %%
df["product_details"] = df["product_details"].apply(flatten)

# %%
df_details = df["product_details"].apply(pd.Series)
df_details.head()
# Out:
#    Style Code              Closure       Pockets        Fabric Pattern  \
# 0  1005COMBO2              Elastic  Side Pockets  Cotton Blend   Solid
# 1    1005BLUE  Drawstring, Elastic  Side Pockets  Cotton Blend   Solid
# 2  1005COMBO4              Elastic  Side Pockets  Cotton Blend   Solid
# 3  1005COMBO3              Elastic  Side Pockets  Cotton Blend   Solid
# 4  1005COMBO1  Drawstring, Elastic  Side Pockets  Cotton Blend   Solid
#
#          Color Sales Package Fabric Care Ideal For Type  ... Sleeve in inch  \
# 0   Multicolor           NaN         NaN       NaN  NaN  ...            NaN
# 1         Blue           NaN         NaN       NaN  NaN  ...            NaN
# 2   Multicolor           NaN         NaN       NaN  NaN  ...            NaN
# 3   Multicolor           NaN         NaN       NaN  NaN  ...            NaN
# 4  Brown, Grey           NaN         NaN       NaN  NaN  ...            NaN
#
#   Brand Model Number Shade Thumb Hole Length Strap Material Weave type  \
# 0   NaN          NaN   NaN        NaN    NaN            NaN        NaN
# 1   NaN          NaN   NaN        NaN    NaN            NaN        NaN
# 2   NaN          NaN   NaN        NaN    NaN            NaN        NaN
# 3   NaN          NaN   NaN        NaN    NaN            NaN        NaN
# 4   NaN          NaN   NaN        NaN    NaN            NaN        NaN
#
#   Fabric care Coat Type
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN
#
# [5 rows x 127 columns]

# %%
keep = ["Closure", "Pockets", "Fabric", "Pattern", "Color"]
df_details = df_details[keep]
df_details.head()
# Out:
#                Closure       Pockets        Fabric Pattern        Color
# 0              Elastic  Side Pockets  Cotton Blend   Solid   Multicolor
# 1  Drawstring, Elastic  Side Pockets  Cotton Blend   Solid         Blue
# 2              Elastic  Side Pockets  Cotton Blend   Solid   Multicolor
# 3              Elastic  Side Pockets  Cotton Blend   Solid   Multicolor
# 4  Drawstring, Elastic  Side Pockets  Cotton Blend   Solid  Brown, Grey

# %%
df_details = df_details.add_prefix("prod_det_")
df = pd.concat([df, df_details], axis=1)

# %%
df.head()
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  {'Style Code': '1005COMBO2', 'Closure': 'Elast...  Shyam Enterprises
# 1  {'Style Code': '1005BLUE', 'Closure': 'Drawstr...  Shyam Enterprises
# 2  {'Style Code': '1005COMBO4', 'Closure': 'Elast...  Shyam Enterprises
# 3  {'Style Code': '1005COMBO3', 'Closure': 'Elast...  Shyam Enterprises
# 4  {'Style Code': '1005COMBO1', 'Closure': 'Draws...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url     prod_det_Closure  \
# 0  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 1  https://www.flipkart.com/yorker-solid-men-blue...  Drawstring, Elastic
# 2  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 3  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 4  https://www.flipkart.com/yorker-solid-men-brow...  Drawstring, Elastic
#
#   prod_det_Pockets prod_det_Fabric prod_det_Pattern prod_det_Color
# 0     Side Pockets    Cotton Blend            Solid     Multicolor
# 1     Side Pockets    Cotton Blend            Solid           Blue
# 2     Side Pockets    Cotton Blend            Solid     Multicolor
# 3     Side Pockets    Cotton Blend            Solid     Multicolor
# 4     Side Pockets    Cotton Blend            Solid    Brown, Grey

# %%
df["product_details"] = df_details.astype(str).apply(" ".join, axis=1)

# %%
df["product_details"]
# Out:
# 0        Elastic Side Pockets Cotton Blend Solid Multic...
# 1        Drawstring, Elastic Side Pockets Cotton Blend ...
# 2        Elastic Side Pockets Cotton Blend Solid Multic...
# 3        Elastic Side Pockets Cotton Blend Solid Multic...
# 4        Drawstring, Elastic Side Pockets Cotton Blend ...
#                                ...
# 28075                          Zipper nan Nylon Solid Blue
# 28076               Drawstring nan Polycotton Printed Blue
# 28077                Button 2 POCKETS Tweed Checkered Grey
# 28078                          Zipper nan Nylon Solid Blue
# 28079                          Zipper nan Nylon Solid Blue
# Name: product_details, Length: 28080, dtype: object

# %%
df.head()
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 1  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
# 2  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 3  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 4  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url     prod_det_Closure  \
# 0  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 1  https://www.flipkart.com/yorker-solid-men-blue...  Drawstring, Elastic
# 2  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 3  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 4  https://www.flipkart.com/yorker-solid-men-brow...  Drawstring, Elastic
#
#   prod_det_Pockets prod_det_Fabric prod_det_Pattern prod_det_Color
# 0     Side Pockets    Cotton Blend            Solid     Multicolor
# 1     Side Pockets    Cotton Blend            Solid           Blue
# 2     Side Pockets    Cotton Blend            Solid     Multicolor
# 3     Side Pockets    Cotton Blend            Solid     Multicolor
# 4     Side Pockets    Cotton Blend            Solid    Brown, Grey

# %%
#cat_fields = ["category", "sub_category", "brand", "seller"]
#df[cat_fields] = df[cat_fields].apply(" ".join, axis=1)

# %%
cols = ["title", "description", "sub_category", "product_details", "brand", "category", "seller"]
df["extra_fields"] = df[cols].apply(lambda r: " ".join(r.astype(str)), axis=1)

# %%
df["extra_fields"]
# Out:
# 0        Solid Women Multicolor Track Pants Yorker trac...
# 1        Solid Men Blue Track Pants Yorker trackpants m...
# 2        Solid Men Multicolor Track Pants Yorker trackp...
# 3        Solid Women Multicolor Track Pants Yorker trac...
# 4        Solid Women Brown, Grey Track Pants Yorker tra...
#                                ...
# 28075    Sleeveless Solid Men Jacket  Winter Wear Zippe...
# 28076    Printed Men Blue Regular Shorts  Bottomwear Dr...
# 28077    Checkered Single Breasted Casual Women Full Sl...
# 28078    Full Sleeve Solid Men Casual Jacket  Winter We...
# 28079    Full Sleeve Solid Women Casual Jacket ‘OKANE’ ...
# Name: extra_fields, Length: 28080, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28080 entries, 0 to 28079
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pid               28080 non-null  object
#  1   title             28080 non-null  object
#  2   description       28080 non-null  object
#  3   brand             28080 non-null  object
#  4   category          28080 non-null  object
#  5   sub_category      28080 non-null  object
#  6   product_details   28080 non-null  object
#  7   seller            28080 non-null  object
#  8   out_of_stock      28080 non-null  bool
#  9   selling_price     28080 non-null  object
#  10  discount          28080 non-null  object
#  11  actual_price      28080 non-null  object
#  12  average_rating    28080 non-null  object
#  13  url               28080 non-null  object
#  14  prod_det_Closure  4257 non-null   object
#  15  prod_det_Pockets  1678 non-null   object
#  16  prod_det_Fabric   25959 non-null  object
#  17  prod_det_Pattern  25692 non-null  object
#  18  prod_det_Color    14185 non-null  object
#  19  extra_fields      28080 non-null  object
# dtypes: bool(1), object(19)
# memory usage: 4.1+ MB

# %%
df.head()
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 1  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
# 2  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 3  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 4  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
#
#    out_of_stock selling_price discount actual_price average_rating  \
# 0         False           921  69% off        2,999            3.9
# 1         False           499  66% off        1,499            3.9
# 2         False           931  68% off        2,999            3.9
# 3         False           911  69% off        2,999            3.9
# 4         False           943  68% off        2,999            3.9
#
#                                                  url     prod_det_Closure  \
# 0  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 1  https://www.flipkart.com/yorker-solid-men-blue...  Drawstring, Elastic
# 2  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 3  https://www.flipkart.com/yorker-solid-men-mult...              Elastic
# 4  https://www.flipkart.com/yorker-solid-men-brow...  Drawstring, Elastic
#
#   prod_det_Pockets prod_det_Fabric prod_det_Pattern prod_det_Color  \
# 0     Side Pockets    Cotton Blend            Solid     Multicolor
# 1     Side Pockets    Cotton Blend            Solid           Blue
# 2     Side Pockets    Cotton Blend            Solid     Multicolor
# 3     Side Pockets    Cotton Blend            Solid     Multicolor
# 4     Side Pockets    Cotton Blend            Solid    Brown, Grey
#
#                                         extra_fields
# 0  Solid Women Multicolor Track Pants Yorker trac...
# 1  Solid Men Blue Track Pants Yorker trackpants m...
# 2  Solid Men Multicolor Track Pants Yorker trackp...
# 3  Solid Women Multicolor Track Pants Yorker trac...
# 4  Solid Women Brown, Grey Track Pants Yorker tra...

# %%
text_cols = [
    "title", "description", "extra_fields",
    "brand", "category", "sub_category","seller",
    "prod_det_Closure", "prod_det_Pockets", "prod_det_Fabric", "prod_det_Pattern", "prod_det_Color"
]

for c in text_cols:
    if c in df.columns:
        df[c] = df[c].replace("nan", "").fillna("").astype(str)
        df[c + "_terms"] = df[c].map(build_terms)

# %%
df.head()
# Out:
#                 pid                                title  \
# 0  TKPFCZ9EA7H5FYZH   Solid Women Multicolor Track Pants
# 1  TKPFCZ9EJZV2UVRZ           Solid Men Blue Track Pants
# 2  TKPFCZ9EHFCY5Z4Y     Solid Men Multicolor Track Pants
# 3  TKPFCZ9ESZZ7YWEF   Solid Women Multicolor Track Pants
# 4  TKPFCZ9EVXKBSUD7  Solid Women Brown, Grey Track Pants
#
#                                          description brand  \
# 0  Yorker trackpants made from 100% rich combed c...  York
# 1  Yorker trackpants made from 100% rich combed c...  York
# 2  Yorker trackpants made from 100% rich combed c...  York
# 3  Yorker trackpants made from 100% rich combed c...  York
# 4  Yorker trackpants made from 100% rich combed c...  York
#
#                    category sub_category  \
# 0  Clothing and Accessories   Bottomwear
# 1  Clothing and Accessories   Bottomwear
# 2  Clothing and Accessories   Bottomwear
# 3  Clothing and Accessories   Bottomwear
# 4  Clothing and Accessories   Bottomwear
#
#                                      product_details             seller  \
# 0  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 1  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
# 2  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 3  Elastic Side Pockets Cotton Blend Solid Multic...  Shyam Enterprises
# 4  Drawstring, Elastic Side Pockets Cotton Blend ...  Shyam Enterprises
#
#    out_of_stock selling_price  ...  \
# 0         False           921  ...
# 1         False           499  ...
# 2         False           931  ...
# 3         False           911  ...
# 4         False           943  ...
#
#                                   extra_fields_terms brand_terms  \
# 0  [solid, women, multicolor, track, pant, yorker...      [york]
# 1  [solid, men, blue, track, pant, yorker, trackp...      [york]
# 2  [solid, men, multicolor, track, pant, yorker, ...      [york]
# 3  [solid, women, multicolor, track, pant, yorker...      [york]
# 4  [solid, women, brown, grey, track, pant, yorke...      [york]
#
#        category_terms sub_category_terms        seller_terms  \
# 0  [cloth, accessori]       [bottomwear]  [shyam, enterpris]
# 1  [cloth, accessori]       [bottomwear]  [shyam, enterpris]
# 2  [cloth, accessori]       [bottomwear]  [shyam, enterpris]
# 3  [cloth, accessori]       [bottomwear]  [shyam, enterpris]
# 4  [cloth, accessori]       [bottomwear]  [shyam, enterpris]
#
#   prod_det_Closure_terms prod_det_Pockets_terms prod_det_Fabric_terms  \
# 0                [elast]         [side, pocket]       [cotton, blend]
# 1       [drawstr, elast]         [side, pocket]       [cotton, blend]
# 2                [elast]         [side, pocket]       [cotton, blend]
# 3                [elast]         [side, pocket]       [cotton, blend]
# 4       [drawstr, elast]         [side, pocket]       [cotton, blend]
#
#   prod_det_Pattern_terms prod_det_Color_terms
# 0                [solid]         [multicolor]
# 1                [solid]               [blue]
# 2                [solid]         [multicolor]
# 3                [solid]         [multicolor]
# 4                [solid]        [brown, grey]
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 4. Numeric fields
#
# Consider the fields out_of_stock, selling_price, discount, actual_price, and average_rating. Decide how these should be handled during pre-processing to use in further search. Should they be indexed as textual terms?

# %% [markdown]
# No indexamos los campos numéricos como texto. Estos cinco campos no aportan información semántica sobre el producto, sino cuantitativa, útiles para filtrar u ordenar los resultados. Durante el **pre-processing** se convierten a formato numérico o booleano, pero no se incluyen en el campo `extra_field` ni en el índice invertido.

# %%
num_fields = ["selling_price", "discount", "actual_price", "average_rating"]
for col in num_fields:
    df[col] = pd.to_numeric(
        df[col].astype(str).str.replace(r"[^\d.]", "", regex=True)
    )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28080 entries, 0 to 28079
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pid                     28080 non-null  object
#  1   title                   28080 non-null  object
#  2   description             28080 non-null  object
#  3   brand                   28080 non-null  object
#  4   category                28080 non-null  object
#  5   sub_category            28080 non-null  object
#  6   product_details         28080 non-null  object
#  7   seller                  28080 non-null  object
#  8   out_of_stock            28080 non-null  bool
#  9   selling_price           28078 non-null  float64
#  10  discount                27225 non-null  float64
#  11  actual_price            27303 non-null  float64
#  12  average_rating          25819 non-null  float64
#  13  url                     28080 non-null  object
#  14  prod_det_Closure        28080 non-null  object
#  15  prod_det_Pockets        28080 non-null  object
#  16  prod_det_Fabric         28080 non-null  object
#  17  prod_det_Pattern        28080 non-null  object
#  18  prod_det_Color          28080 non-null  object
#  19  extra_fields            28080 non-null  object
#  20  title_terms             28080 non-null  object
#  21  description_terms       28080 non-null  object
#  22  extra_fields_terms      28080 non-null  object
#  23  brand_terms             28080 non-null  object
#  24  category_terms          28080 non-null  object
#  25  sub_category_terms      28080 non-null  object
#  26  seller_terms            28080 non-null  object
#  27  prod_det_Closure_terms  28080 non-null  object
#  28  prod_det_Pockets_terms  28080 non-null  object
#  29  prod_det_Fabric_terms   28080 non-null  object
#  30  prod_det_Pattern_terms  28080 non-null  object
#  31  prod_det_Color_terms    28080 non-null  object
# dtypes: bool(1), float64(4), object(27)
# memory usage: 6.7+ MB

# %% [markdown]
# # Part II: EDA

# %% [markdown]
# When working with data, it is important to have a better understanding of the content and some statistics. Provide an exploratory data analysis to describe the dataset you are working on in this project and explain the decisions made for the analysis. For example, word counting distribution, average sentence length, vocabulary size, ranking of products based on rating, price, discount, top sellers and brands, out_of_stock distribution, word clouds for the most frequent words, and entity recognition. Feel free to do the exploratory analysis and report your findings in the report.

# %%
def ranking(df, by, n=10, ascending=False, cols=None):
    cols = cols or df.columns
    return (df.dropna(subset=[by])
              .sort_values(by=by, ascending=ascending)
              .loc[:, cols]
              .head(n))

def top(series, n=20, title=None):
    counts = (series.astype(str)
                    .str.strip()
                    .replace("", pd.NA)
                    .dropna()
                    .value_counts()
                    .head(n))

    plt.figure(figsize=(8, 5))
    plt.barh(counts.index[::-1], counts.values[::-1])
    plt.title(title or f"Top {n}")
    plt.xlabel("Count")
    plt.ylabel(series.name or "Value")
    plt.tight_layout()
    plt.show()

# %%
len(df) # number of rows
# Out:
# 28080

# %%
df[num_fields].describe().T # main statistics
# Out:
#                   count         mean         std    min    25%     50%  \
# selling_price   28078.0   705.635088  549.681489   99.0  390.0   545.0
# discount        27225.0    50.256896   16.887287    1.0   40.0    53.0
# actual_price    27303.0  1455.528110  939.977456  150.0  849.0  1199.0
# average_rating  25819.0     3.627724    0.663429    1.0    3.2     3.8
#
#                    75%      max
# selling_price    820.0   7999.0
# discount          63.0     87.0
# actual_price    1799.0  12999.0
# average_rating     4.1      5.0

# %%
def top_words_table(series, n=20, lowercase=True, stopwords=None):
    stop = set(stopwords or [])
    def tokens(x):
        if isinstance(x, (list, tuple, set)):
            xs = [str(t) for t in x]
        else:
            s = str(x)
            if lowercase: s = s.lower()
            xs = s.split()
        return [w for w in xs if w and w not in stop]

    cnt = Counter()
    for x in series:
        cnt.update(tokens(x))

    return pd.DataFrame(cnt.most_common(n), columns=["word", "count"])

# %%
ranking(df, by="average_rating", n=10, ascending=False,
              cols=["pid","title","brand","average_rating","selling_price"]) # ranking products by rating
# Out:
#                     pid                                            title  \
# 22361  BRFFM8J3XCQHKYYA                           Men Brief  (Pack of 5)
# 8403   VESFN9F35YWEEHDG                      VIP Women Vest  (Pack of 8)
# 14764  TSHFUEUZDF7J7QDW     Graphic Print Women Round Neck White T-Shirt
# 13240  BRFFFYHUQGBFXZTG                           Men Brief  (Pack of 5)
# 10472  SHTFZZFERN6EPZNM  Men Slim Fit Printed Spread Collar Casual Shirt
# 12351  TSHFKH7VZA54W6UF          Printed Women Hooded Neck Black T-Shirt
# 13242  BRFFFEH4B6JVT5A5                           Men Brief  (Pack of 5)
# 12349  TSHFGMGPBJXHH3XZ             Printed Men Hooded Neck Grey T-Shirt
# 12348  TSHFCWYJYURDMMBU       Solid Women Round Neck Black, Grey T-Shirt
# 10470  TSHFQ4FWQ42YYX9F                Solid Women Polo Neck Red T-Shirt
#
#             brand  average_rating  selling_price
# 22361         COL             5.0          385.0
# 8403                          5.0         1108.0
# 14764     TEE BUD             5.0          349.0
# 13240  VIKING.INE             5.0          699.0
# 10472     True Bl             5.0         1119.0
# 12351     ATTIITU             5.0         1499.0
# 13242  VIKING.INE             5.0          699.0
# 12349     ATTIITU             5.0          499.0
# 12348     ATTIITU             5.0          449.0
# 10470     True Bl             5.0          599.0

# %%
ranking(df, by="selling_price", n=10, ascending=True,
              cols=["pid","title","brand","selling_price","discount"]) # ranking products by lower price
# Out:
#                     pid                                            title  \
# 16485  SOCET7QRNHYG9HHB                 Women Mid-Calf/Crew  (Pack of 2)
# 20435  BDAFUBD2EJHFCRNC                              Men Printed Bandana
# 7654   SOCFFGA2FYZQBFXT      Women Color Block Ankle Length  (Pack of 3)
# 24438  SOCFZ7GFAZGYZGR7              Men Solid Ankle Length  (Pack of 3)
# 24437  SOCFZAGJC3VUFQU9            Women Solid Ankle Length  (Pack of 3)
# 24439  SOCFZ7JX39ZEW8GE            Women Solid Ankle Length  (Pack of 3)
# 20253  CAPEX5YHPH3MSGFC                      Cotton 5 panel baseball Cap
# 16402  SUSECSFFVNKG5VGG  Brand Trunk Y- Back Suspenders for Men  (Black)
# 906    TSHF5FRXKGF6A4FH           Printed Women Round Neck White T-Shirt
# 25325  SOCFPR9UF8Q4FCHG                    Men Ankle Length  (Pack of 3)
#
#                    brand  selling_price  discount
# 16485              Welwe           99.0      50.0
# 20435           T10 Spor           99.0      50.0
# 7654   your shopping sto          118.0      76.0
# 24438            ina gro          120.0      69.0
# 24437            ina gro          120.0      69.0
# 24439            ina gro          120.0      69.0
# 20253           T10 Spor          124.0      50.0
# 16402                             125.0      74.0
# 906             Jack Roy          128.0      87.0
# 25325                 Pu          132.0      73.0

# %%
top(df["seller"], n=20, title="Top sellers") # top sellers

# %%
top(df["brand"], n=20, title="Top brands") # top brands

# %%
doc_lengths = df["extra_fields_terms"].astype(str).str.split().map(len)
plt.figure(figsize=(6,4)); plt.hist(doc_lengths, bins=30); plt.title("Doc length"); plt.show()

# %%
word_freq = df["extra_fields_terms"].explode().value_counts().to_dict()

wc = WordCloud(
    width=800,
    height=400,
    background_color="white",
    colormap="viridis",
    max_words=200
).generate_from_frequencies(word_freq)

plt.figure(figsize=(12, 6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Word cloud of the most frequent words", fontsize=16)
plt.show()
